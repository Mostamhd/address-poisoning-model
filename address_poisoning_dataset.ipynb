# %% [markdown]
# ## imports and DB connection

# %%
import pandas as pd
import mysql.connector
import time
import os
import csv
import networkx as nx
import matplotlib.pyplot as plt
from IPython.display import display
# !pip install scipy pandas networkx matplotlib

# %matplotlib inline
# Out:
# /home/moustafa-mahmoud/.virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# Requirement already satisfied: scipy in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (1.7.3)
# Requirement already satisfied: pandas in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: networkx in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (2.6.3)
# Requirement already satisfied: matplotlib in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (3.5.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from scipy) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from pandas) (2024.1)
# Requirement already satisfied: cycler>=0.10 in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: typing-extensions in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (4.7.1)
# Requirement already satisfied: six>=1.5 in /home/moustafa-mahmoud/.local/share/virtualenvs/address_poisoning_dataset-Hfv8_GC8/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # PART 1: DATASET CSVs CREATION

# %% [markdown]
# ### Establishing connection to the ethereum database

# %%
# Database connection details
DB_HOST = '192.168.255.83'
DB_USER = 'moustafa.mahmoud'
DB_PASSWORD = '$*5f9fBvwzR!yf'
DB_NAME = 'eth' 

db_connection = mysql.connector.connect(
    host=DB_HOST,
    user=DB_USER,
    password=DB_PASSWORD,
    database=DB_NAME
)

# %% [markdown]
# ### database queries

# %%
def get_address_id(address_hash):
    cursor = db_connection.cursor(dictionary=True)
    query = "SELECT id FROM address WHERE hash = %s"
    cursor.execute(query, (address_hash,))
    result = cursor.fetchone()
    cursor.close()
    return result['id'] if result else None

def get_address_hash(address_id):
    cursor = db_connection.cursor(dictionary=True)
    query = "SELECT hash FROM address WHERE id = %s"
    cursor.execute(query, (address_id,))
    result = cursor.fetchone()
    cursor.close()
    return result['hash'] if result else None

def get_erc20_transactions(address_id):
    """
    columns for this query :
    id hash tx_index gas_price_in_wei gas_used block_id block_timestamp total_eth_transfer total_deployment total_erc20_transfer type status base_fee max_fee priority_fee input reverse_hash total_erc721_transfer total_internal_transfer input output tx_id index_in_tx contract_id crypto_amount
    """

    cursor = db_connection.cursor(dictionary=True)
    # Query for getting all erc20 transaction 
    query = """
        SELECT * 
        FROM transaction t 
        JOIN address_address_erc20_transaction atx ON t.id = atx.tx_id 
        WHERE atx.output = %s OR atx.input = %s
        ORDER BY t.block_timestamp ASC 
    """
    cursor.execute(query, (address_id,address_id))
    results = cursor.fetchall()
    cursor.close()
    return results

def get_eth_transactions(address_id):
    """
    columns for this query :
    id hash tx_index gas_price_in_wei gas_used block_id block_timestamp total_eth_transfer total_deployment total_erc20_transfer type status base_fee max_fee priority_fee input reverse_hash total_erc721_transfer total_internal_transfer input output tx_id crypto_amount
    """

    cursor = db_connection.cursor(dictionary=True)
    # Query for getting eth transactions
    query = """
        SELECT * 
        FROM transaction t 
        JOIN address_address_transaction atx ON t.id = atx.tx_id 
        WHERE atx.output = %s OR atx.input = %s
        ORDER BY t.block_timestamp ASC 
    """

    cursor.execute(query, (address_id,address_id))
    results = cursor.fetchall()
    cursor.close()
    return results

# %% [markdown]
# ### Helper functions to better manage writing the dataset into csvs

# %%
def write_checkpoint(index):
    with open(CHECKPOINT_FILE, 'w') as f:
        f.write(str(index))

def read_checkpoint():
    if os.path.exists(CHECKPOINT_FILE):
        with open(CHECKPOINT_FILE, 'r') as f:
            return int(f.read().strip())
    return 0

def print_progress(index, total, num_transactions, address):
    progress = (index / total) * 100
    print(f"Processing address {index + 1}/{total} ({progress:.2f}%), Address: {address}, Transactions: {num_transactions}")

# %% [markdown]
# ### Genereating a single csv dataset of all the erc20 trascations for an address flagged as an address poisining address

# %%
# Output files
OUTPUT_FILE = 'address_poisoning_transactions.csv'
CHECKPOINT_FILE = 'address_poisoning_transactions_checkpoint.txt'

# Load the CSV file
df = pd.read_csv('address_poisoning_addresses_list.csv')

# Get the last processed index
last_index = read_checkpoint()

# Total number of addresses
total_addresses = len(df)

# Open the output file in append mode
with open(OUTPUT_FILE, 'a') as output_file:
    # Write headers if the file is empty
    if os.path.getsize(OUTPUT_FILE) == 0:
        headers = ['from', 'to', 'hash', 'tx_index', 'gas_price_in_wei', 'gas_used', 'block_id', 'block_timestamp', 'total_eth_transfer', 'total_deployment', 'total_erc20_transfer', 'status', 'base_fee', 'max_fee', 'priority_fee', 'input', 'reverse_hash', 'total_erc721_transfer', 'total_internal_transfer', 'index_in_tx', 'contract_id', 'crypto_amount', 'type', 'class']
        output_file.write(','.join(headers) + '\n')

    # Iterate over each row
    for index in range(last_index, total_addresses):
        row = df.iloc[index]
        address = row['Address']
        currency = row['Currency']
        
        if currency == 'ETH':
            address_id = get_address_id(address)
            if address_id:
                erc20_transactions = get_erc20_transactions(address_id)
                eth_transactions = get_eth_transactions(address_id)
                transactions = erc20_transactions + eth_transactions
                num_transactions = len(transactions)
                print_progress(index, total_addresses, num_transactions, address)
                for tx in transactions:
                    tx_metadata = {
                        'from': address if tx['input'] == address_id else get_address_hash(tx['input']),
                        'to': address if tx['output'] == address_id else get_address_hash(tx['output']),
                        'hash': tx['hash'],
                        'tx_index': tx['tx_index'],
                        'gas_price_in_wei': tx['gas_price_in_wei'],
                        'gas_used': tx['gas_used'],
                        'block_id': tx['block_id'],
                        'block_timestamp': tx['block_timestamp'],
                        'total_eth_transfer': tx['total_eth_transfer'],
                        'total_deployment': tx['total_deployment'],
                        'total_erc20_transfer': tx['total_erc20_transfer'],
                        'status': tx['status'],
                        'base_fee': tx['base_fee'],
                        'max_fee': tx['max_fee'],
                        'priority_fee': tx['priority_fee'],
                        'input': tx['input'],
                        'reverse_hash': tx['reverse_hash'],
                        'total_erc721_transfer': tx['total_erc721_transfer'],
                        'total_internal_transfer': tx['total_internal_transfer'],
                        'index_in_tx': tx['index_in_tx'] if tx in erc20_transactions else None,
                        'contract_id': tx['contract_id'] if tx in erc20_transactions else None,
                        'crypto_amount': tx['crypto_amount'],
                        "type": 'erc20' if tx in erc20_transactions else 'eth',
                        "class": 1
                    }

                    # Write the transaction metadata to the output file
                    output_file.write(','.join(map(str, tx_metadata.values())) + '\n')
            else:
                print_progress(index, total_addresses, 0, address)
        else:
            print_progress(index, total_addresses, 0, address)

        # Write the checkpoint after each iteration
        write_checkpoint(index)
    
        # Sleep to avoid overwhelming the database
        time.sleep(0.1)

print("Processing complete.")

# %% [markdown]
# ### Genereating a single csv dataset of all the erc20 trascations for an address not flagged as an address poisining address

# %%
def get_latest_n_transaction(limit):
    cursor = db_connection.cursor(dictionary=True)
    query = "SELECT hash FROM `address` ORDER BY `address`.`id` DESC LIMIT %s;"
    cursor.execute(query, (limit,))
    result = cursor.fetchall()
    cursor.close()
    return result

def filter_transactions(limit):
    # Read the poisoned addresses from the CSV file
    poisoned_addresses = set()
    with open('address_poisoning_addresses_list.csv', mode='r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            poisoned_addresses.add(row['Address'])

    # Get the latest transactions using the provided function
    latest_transactions = []
    txs = get_latest_n_transaction(limit)
    for tx in txs:
        tx = tx['hash']
        if tx not in poisoned_addresses:
            latest_transactions.append(tx)

    return latest_transactions



def write_transactions_to_csv(transactions, filename="dataset/non_address_poisoning.csv"):
    # Open the CSV file in write mode
    with open(filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        # Write the header
        writer.writerow(["Address", "Currency"])
        # Write the transactions
        for address in transactions:
            writer.writerow([address, "ETH"])


filtered_transactions = filter_transactions(3000)
write_transactions_to_csv(filtered_transactions)

# %%
# Output files
OUTPUT_FILE = 'non_address_poisoning_transactions.csv'
CHECKPOINT_FILE = 'non_address_poisoning_transactions_checkpoint.txt'

# Load the CSV file
df = pd.read_csv('dataset/non_address_poisoning.csv')

# Get the last processed index
last_index = read_checkpoint()

# Total number of addresses
total_addresses = len(df)

# Open the output file in append mode
with open(OUTPUT_FILE, 'a') as output_file:
    # Write headers if the file is empty
    if os.path.getsize(OUTPUT_FILE) == 0:
        headers = ['from', 'to', 'hash', 'tx_index', 'gas_price_in_wei', 'gas_used', 'block_id', 'block_timestamp', 'total_eth_transfer', 'total_deployment', 'total_erc20_transfer', 'status', 'base_fee', 'max_fee', 'priority_fee', 'input', 'reverse_hash', 'total_erc721_transfer', 'total_internal_transfer', 'index_in_tx', 'contract_id', 'crypto_amount', 'type', 'class']
        output_file.write(','.join(headers) + '\n')

    # Iterate over each row
    for index in range(last_index, total_addresses):
        row = df.iloc[index]
        address = row['Address']
        currency = row['Currency']
        
        if currency == 'ETH':
            address_id = get_address_id(address)
            if address_id:
                erc20_transactions = get_erc20_transactions(address_id)
                eth_transactions = get_eth_transactions(address_id)
                transactions = erc20_transactions + eth_transactions
                num_transactions = len(transactions)
                print_progress(index, total_addresses, num_transactions, address)
                for tx in transactions:
                    tx_metadata = {
                        'from': address if tx['input'] == address_id else get_address_hash(tx['input']),
                        'to': address if tx['output'] == address_id else get_address_hash(tx['output']),
                        'hash': tx['hash'],
                        'tx_index': tx['tx_index'],
                        'gas_price_in_wei': tx['gas_price_in_wei'],
                        'gas_used': tx['gas_used'],
                        'block_id': tx['block_id'],
                        'block_timestamp': tx['block_timestamp'],
                        'total_eth_transfer': tx['total_eth_transfer'],
                        'total_deployment': tx['total_deployment'],
                        'total_erc20_transfer': tx['total_erc20_transfer'],
                        'status': tx['status'],
                        'base_fee': tx['base_fee'],
                        'max_fee': tx['max_fee'],
                        'priority_fee': tx['priority_fee'],
                        'input': tx['input'],
                        'reverse_hash': tx['reverse_hash'],
                        'total_erc721_transfer': tx['total_erc721_transfer'],
                        'total_internal_transfer': tx['total_internal_transfer'],
                        'index_in_tx': tx['index_in_tx'] if tx in erc20_transactions else None,
                        'contract_id': tx['contract_id'] if tx in erc20_transactions else None,
                        'crypto_amount': tx['crypto_amount'],
                        "type": 'erc20' if tx in erc20_transactions else 'eth',
                        "class": 0
                    }

                    # Write the transaction metadata to the output file
                    output_file.write(','.join(map(str, tx_metadata.values())) + '\n')
            else:
                print_progress(index, total_addresses, 0, address)
        else:
            print_progress(index, total_addresses, 0, address)

        # Write the checkpoint after each iteration
        write_checkpoint(index)
    
        # Sleep to avoid overwhelming the database
        time.sleep(0.1)

print("Processing complete.")
# Out:
# Processing address 1/3000 (0.00%), Address: 0x04aa99a04965e24f4a1320e7c79b67b1d63743e7, Transactions: 0
# Processing address 2/3000 (0.03%), Address: 0xcbf38c3b796152b2b7da1df284e6b0db05ef2027, Transactions: 0
# Processing address 3/3000 (0.07%), Address: 0x38d75ad9f8bbf3e7a67a57f4ad70a6beb5254666, Transactions: 0
# Processing address 4/3000 (0.10%), Address: 0x98a00198f95273590b88e712b528076ed364c025, Transactions: 0
# Processing address 5/3000 (0.13%), Address: 0x7f93fd7877fdb9f2f4698f5cdac06a1a3ab667f6, Transactions: 0
# Processing address 6/3000 (0.17%), Address: 0x1099b3359a985bd6f96951a618e12641587bc1a3, Transactions: 0
# Processing address 7/3000 (0.20%), Address: 0x30e4f0f2fb227f4d83a8a3e3618089bed82d5db3, Transactions: 0
# Processing address 8/3000 (0.23%), Address: 0xe4aed046268b3f740a0df44cad61eafb3075069c, Transactions: 0
# Processing address 9/3000 (0.27%), Address: 0xf8f4976b81d2e6d667912f19f9219fbc6217e971, Transactions: 0
# Processing address 10/3000 (0.30%), Address: 0x544b0c8ccf2382fab1e94d56bd86711ad2a03259, Transactions: 0
# Processing address 11/3000 (0.33%), Address: 0x7d220d85c9419c405769e3075553b45a9ce73fda, Transactions: 0
# Processing address 12/3000 (0.37%), Address: 0xd2c2c1a999a5a5f32dfb1ad89ea8e6e79f2a96a9, Transactions: 0
# Processing address 13/3000 (0.40%), Address: 0x7b668c4db77bffe535506b677b8f06dfb1bfdd4a, Transactions: 0
# Processing address 14/3000 (0.43%), Address: 0x325877480489209af7d962ef013d67c225c624d3, Transactions: 0
# Processing address 15/3000 (0.47%), Address: 0x0fcf6752ec8823c4c5b921dd694b3e6b561f4191, Transactions: 0
# Processing address 16/3000 (0.50%), Address: 0x5560184a1f34133c3a28490b2c172744626fe5a5, Transactions: 0
# Processing address 17/3000 (0.53%), Address: 0x4254fc301df31a77051ec155d606b95e30c99b8a, Transactions: 0
# Processing address 18/3000 (0.57%), Address: 0x6884597944681f0cd5a441e7f86fe953e5401e4b, Transactions: 0
# Processing address 19/3000 (0.60%), Address: 0x45d104a9cd425c253eed98ec5d957d76d308339d, Transactions: 0
# Processing address 20/3000 (0.63%), Address: 0xa71245be12bb9f7f3900750c6f3c8880d56312a7, Transactions: 0
# Processing address 21/3000 (0.67%), Address: 0x5791403e260eb73f608123f260099c939a20c73c, Transactions: 0
# Processing address 22/3000 (0.70%), Address: 0x44b17db12da4b2a0ae50ef782b5e14c4609e5032, Transactions: 0
# Processing address 23/3000 (0.73%), Address: 0xa8671e0e282be84a9d468c2ec3ff1caf7e160b17, Transactions: 0
# Processing address 24/3000 (0.77%), Address: 0x0902713aa08b8556161b67369cac2ecde0bc79bf, Transactions: 0
# Processing address 25/3000 (0.80%), Address: 0xde463ff14e7b6f5ba9d7068918ad3905a1733bf6, Transactions: 0
# Processing address 26/3000 (0.83%), Address: 0xc92279e68935b07a6925928d1524fb8d13af71ad, Transactions: 0
# Processing address 27/3000 (0.87%), Address: 0x11238cdb2ad2aef7e784e515add57a8fdefe333c, Transactions: 0
# Processing address 28/3000 (0.90%), Address: 0x7c90914603d00076b67b4685a4cfb998ffe0387c, Transactions: 0
# Processing address 29/3000 (0.93%), Address: 0x8caf1a739237313c4ecd01ee424b272bda52506f, Transactions: 0
# Processing address 30/3000 (0.97%), Address: 0x2d94b2a09838683abe0b744e8a90dbb506727fd2, Transactions: 0
# Processing address 31/3000 (1.00%), Address: 0xd9200c2b88503dc22f826aa3d4bce234fcf88de2, Transactions: 0
# Processing address 32/3000 (1.03%), Address: 0x8bdb06f4e6d7c3e78f06da262e05746b2ff20b03, Transactions: 0
# Processing address 33/3000 (1.07%), Address: 0x805a2a70b8460fbcf4eb5d3c0fab1c30bec06ad8, Transactions: 0
# Processing address 34/3000 (1.10%), Address: 0x9e0fda380f3bb42cee133b87d7bb13ea5367d27d, Transactions: 0
# Processing address 63/3000 (2.07%), Address: 0xb043e264cb3c5589bdf67c15d2215befae0e4b37, Transactions: 0
# Processing address 64/3000 (2.10%), Address: 0xd0427a7bffd256b97015dafc1f3f425204274968, Transactions: 0
# Processing address 65/3000 (2.13%), Address: 0x544bed2e956b3e8e6ad9f69f282ddec66a293259, Transactions: 0
# Processing address 66/3000 (2.17%), Address: 0x34eda8560f3ce7ad09066bb390b3d7fa504f4fa2, Transactions: 0
# Processing address 67/3000 (2.20%), Address: 0x39e8f777e128fee570973117b45a9ec2850b1d43, Transactions: 0
# Processing address 68/3000 (2.23%), Address: 0xf8d04e6032049cf0001136fd71b3ad5e16aaeb78, Transactions: 0
# Processing address 69/3000 (2.27%), Address: 0x09da7ef4f945fb35567211662e3e72c767b1ed59, Transactions: 0
# Processing address 70/3000 (2.30%), Address: 0xf3781f2dab315d0582552416ec1d35da30027601, Transactions: 0
# Processing address 71/3000 (2.33%), Address: 0x28e6cc1eba737650973f3754b0c5259515227811, Transactions: 0
# Processing address 72/3000 (2.37%), Address: 0x136c6532ab7800758cda66bb30934f0999fb0d7d, Transactions: 0
# Processing address 73/3000 (2.40%), Address: 0x30e4866ab5fb3bc1733c1808f56c5511e46b5db3, Transactions: 0
# Processing address 74/3000 (2.43%), Address: 0x8f18c2581bcdc42eaf26480b1d3806653cecdbcd, Transactions: 0
# Processing address 75/3000 (2.47%), Address: 0x98e38ad1a008ca517d1ab2dedb875274161723f7, Transactions: 0
# Processing address 76/3000 (2.50%), Address: 0x1f8106aaa6706b1c807005c8badf111d3b2c805c, Transactions: 0
# Processing address 77/3000 (2.53%), Address: 0x4cead49e9ba857dc955cdfdbee07422175871600, Transactions: 0
# Processing address 78/3000 (2.57%), Address: 0x98a07c64795e4211d43e98c61d9f4dc03d78c025, Transactions: 0
# Processing address 79/3000 (2.60%), Address: 0x76bd306ec3c23d866bdc7358f0a8265a6dc62f4b, Transactions: 0
# Processing address 80/3000 (2.63%), Address: 0x544b9ad332f36bedb3eb7f100ca98dcbcbe63259, Transactions: 0
# Processing address 81/3000 (2.67%), Address: 0x41b9a86c22cc9c02038bc8f5e585976f1ded50de, Transactions: 0
# Processing address 82/3000 (2.70%), Address: 0xacb4b06feb09cd1c9de77ed884594e5731d225c1, Transactions: 0
# Processing address 83/3000 (2.73%), Address: 0x0aab246eb1ef5e042c299a358c79c763534d43c1, Transactions: 0
# Processing address 84/3000 (2.77%), Address: 0xea4bdbdd869c2b8fa6a585ac724bcaf0bf13eba7, Transactions: 0
# Processing address 85/3000 (2.80%), Address: 0xa5d4a315244ed5fddf18cd9eacaa98847f35b820, Transactions: 0
# Processing address 86/3000 (2.83%), Address: 0xd4ef2f336cd3daee08f7c6a1e2c965b1b93d8a2a, Transactions: 0
# Processing address 87/3000 (2.87%), Address: 0x683f1524ca69761fedb64b370f729ce67cabd5ef, Transactions: 0
# Processing address 88/3000 (2.90%), Address: 0x78ff899d3104e31508b671b7c94a1ea1b7c25e4d, Transactions: 0
# Processing address 143/3000 (4.73%), Address: 0xb9f5e6986e49be22e23a5a9f20a73f8fae2194b3, Transactions: 1
# Processing address 144/3000 (4.77%), Address: 0x285ff91c8ba982502f59dfac15329eb2884ffa5a, Transactions: 1
# Processing address 145/3000 (4.80%), Address: 0xe253d64311d4d24b16460cd4e33b88b3bed61790, Transactions: 1
# Processing address 146/3000 (4.83%), Address: 0xeaa4787db646ec83fb7cd738366a8e6f466f009f, Transactions: 0
# Processing address 147/3000 (4.87%), Address: 0xa48ecc1f52ac8cd55c21ea4309909eb27de58fb1, Transactions: 1
# Processing address 148/3000 (4.90%), Address: 0x48775fe388c9d1a884b5458b43d9328c7cfaa3d3, Transactions: 1
# Processing address 149/3000 (4.93%), Address: 0x31ddf8e5708df771b6d916cc6d1578bc043b0590, Transactions: 1
# Processing address 150/3000 (4.97%), Address: 0xc8f29a0efbfc90ad5479b07c912895cc568314a4, Transactions: 1
# Processing address 151/3000 (5.00%), Address: 0xb9c147dcf1c326678b1863d969ccf7c0df067622, Transactions: 1
# Processing address 152/3000 (5.03%), Address: 0x1e6b355d69634d38ef7fad555815b791ba78c22a, Transactions: 1
# Processing address 153/3000 (5.07%), Address: 0x76db66cf72be2abd0bae74c6c6616894675f0016, Transactions: 1
# Processing address 154/3000 (5.10%), Address: 0x8e7663af93815eea6536e98b1d52bef1a0ea6f47, Transactions: 1
# Processing address 155/3000 (5.13%), Address: 0x148d6a91675780c107515f267944323ea51f9d13, Transactions: 1
# Processing address 156/3000 (5.17%), Address: 0x87f7349b5dfdb93107dc1b0e7426cac452e654ef, Transactions: 1
# Processing address 157/3000 (5.20%), Address: 0x613b4ca7977cc790c4411335a5052bef9e2a8cf4, Transactions: 1
# Processing address 158/3000 (5.23%), Address: 0xba03afa7e15d02e7471d848e09d1629cb232007e, Transactions: 1
# Processing address 159/3000 (5.27%), Address: 0xe957f66bc16c2e5fc38471c2ce76a5d957459baa, Transactions: 1
# Processing address 160/3000 (5.30%), Address: 0x7e65d77a112029ef8fa0a9cf5f035dd2d4ed4c5c, Transactions: 1
# Processing address 161/3000 (5.33%), Address: 0x516e631178f0cf50981880485c25a264f51b0127, Transactions: 1
# Processing address 162/3000 (5.37%), Address: 0xce6b08b7d4cf52a3292a4ffcd7681c0b41ae1840, Transactions: 1
# Processing address 163/3000 (5.40%), Address: 0x5db88e029568525a7082cfb3233490de578a598c, Transactions: 1
# Processing address 164/3000 (5.43%), Address: 0xc33a146ebd640f6293939a6ccd97bb194162a38b, Transactions: 1
# Processing address 165/3000 (5.47%), Address: 0x25ba37e3559d0f29a2b99058fdf9e5acc5356491, Transactions: 2
# Processing address 166/3000 (5.50%), Address: 0xe12375ae21803ae9d9431cd17359431979bf9670, Transactions: 1
# Processing address 167/3000 (5.53%), Address: 0x028e9c75baee3010b18d8a930cfde509f5c1e204, Transactions: 1
# Processing address 168/3000 (5.57%), Address: 0xf64ca0087b565abafd25b47e7e5fd1de3ba5b2c8, Transactions: 1
# Processing address 169/3000 (5.60%), Address: 0x563e56d9d111a9257a185e27b1ada09fd7af5217, Transactions: 1
# Processing address 170/3000 (5.63%), Address: 0x268372ab4cc1c2c997654fe734e3822cee413149, Transactions: 1
# Processing address 171/3000 (5.67%), Address: 0x26004e2919cadf00a676182db396ea2310290963, Transactions: 1
# Processing address 172/3000 (5.70%), Address: 0x5899da7f33e2bf28b2133b63173f090c57e01b0b, Transactions: 1
# Processing address 173/3000 (5.73%), Address: 0x5ee6794f58ece019a7a9b36842e3295a1e99d58a, Transactions: 1
# Processing address 174/3000 (5.77%), Address: 0xf2872b495fc3a9fcbff19b1861dc2725d9cb10b8, Transactions: 1
# Processing address 175/3000 (5.80%), Address: 0x025298746e68976bea27406dfc02e436333e820c, Transactions: 1
# Processing address 176/3000 (5.83%), Address: 0x0fe5acd7fa6652b447aae1a541f37d69884d4e8e, Transactions: 1
# Processing address 177/3000 (5.87%), Address: 0xae56b02bfc414189f9a4ccd1237148650be291f3, Transactions: 1
# Processing address 178/3000 (5.90%), Address: 0x0e4ebc00320fb3431ed127f117e4de2319c3a4f3, Transactions: 1
# Processing address 179/3000 (5.93%), Address: 0x4cd43190039d84f324623ff6b950215137936318, Transactions: 1
# Processing address 180/3000 (5.97%), Address: 0x71f826581d61bce213cb8bc7ab9e25372cacd117, Transactions: 2
# Processing address 181/3000 (6.00%), Address: 0x613ae1acbf3a2b6b1c6c99c11af70b2c6eecc1c7, Transactions: 1
# Processing address 182/3000 (6.03%), Address: 0x14c1cf5a22659fc62868ddf60b9cc01e5faf9d13, Transactions: 1
# Processing address 183/3000 (6.07%), Address: 0x6b2805ac782d3aee8b40413847176de8d9a1c15a, Transactions: 1
# Processing address 184/3000 (6.10%), Address: 0x6c1c85663cfee2a738c82db5bf143e03417bfaa8, Transactions: 1
# Processing address 185/3000 (6.13%), Address: 0x04131bd3bc14995bc811fa9707b74e3a434d35f5, Transactions: 1
# Processing address 186/3000 (6.17%), Address: 0xfa4982ffed7c6c59e677edbc30205186322c5d5f, Transactions: 1
# Processing address 187/3000 (6.20%), Address: 0x09b5e9b9beb7fe4a9df0941ddd91956b533f37ff, Transactions: 1
# Processing address 188/3000 (6.23%), Address: 0x6d4256c35433a1cab3a42148a9ab6b93961db899, Transactions: 1
# Processing address 189/3000 (6.27%), Address: 0xdf7decbc1554ccd03f50a1aace77f552a004fe01, Transactions: 1
# Processing address 190/3000 (6.30%), Address: 0x35626a0ca3c9bb01b8ca34e636d57c9cc669ca7e, Transactions: 1
# Processing address 191/3000 (6.33%), Address: 0x7ff59fa4aace73e6a31ab99888615666174d4103, Transactions: 1
# Processing address 192/3000 (6.37%), Address: 0x8267fc70c999b2929c8e1b0ae021e4641261f55a, Transactions: 1
# Processing address 193/3000 (6.40%), Address: 0x23a043f819c515a5398206a36b3a3b8b92cb07e9, Transactions: 1
# Processing address 194/3000 (6.43%), Address: 0x08ed70f551301dc6141ec9478ebdc0dfe5650205, Transactions: 2
# Processing address 195/3000 (6.47%), Address: 0xfe72ffa0e178fca168419eff8a04dd79f597b471, Transactions: 1
# Processing address 196/3000 (6.50%), Address: 0x5725fb988f29c0eec7a12738320a143450c9c8c1, Transactions: 0
# Processing address 224/3000 (7.43%), Address: 0x5b2aaae4ddc14d3a332918df88f9ce80b3039d71, Transactions: 1
# Processing address 225/3000 (7.47%), Address: 0x5a7515c37f54400ce8056ffc52f4e92b8e7f253b, Transactions: 1
# Processing address 226/3000 (7.50%), Address: 0x0064245a234d8a558defa20538b3f45e6f7addea, Transactions: 1
# Processing address 227/3000 (7.53%), Address: 0x32ca528b811e0dcbb803dba92bf04e2c30c25a33, Transactions: 1
# Processing address 228/3000 (7.57%), Address: 0xc3385d8945ade46a923a5dde568b30e5ff42a38b, Transactions: 2
# Processing address 229/3000 (7.60%), Address: 0x118e486b996e040bed958bf03e3a36936f765f15, Transactions: 1
# Processing address 230/3000 (7.63%), Address: 0xf254a96fdd6a42dedf60100e9be7e5d3f2d8de9f, Transactions: 1
# Processing address 231/3000 (7.67%), Address: 0x49fafe1d286352bc53fc015bf556ada93f1088b9, Transactions: 2
# Processing address 232/3000 (7.70%), Address: 0x80980bde2e22720fab6cc5bc10a5dca3d79c0123, Transactions: 1
# Processing address 233/3000 (7.73%), Address: 0x5177792c00e6453660a8d6f15dec16ac560a503c, Transactions: 1
# Processing address 234/3000 (7.77%), Address: 0x2eb102acb905f6bc3cb7b9213c0830a711a23143, Transactions: 1
# Processing address 235/3000 (7.80%), Address: 0xfaa9c0779bfd16369db623b6d155e6757a8606fb, Transactions: 2
# Processing address 236/3000 (7.83%), Address: 0x3c77961f462124f9400aada20dc7144d37741ade, Transactions: 1
# Processing address 237/3000 (7.87%), Address: 0x2373add24a3035f93957b691d18db18a72d3b96a, Transactions: 1
# Processing address 238/3000 (7.90%), Address: 0x80c77daceb0220c67246a4a587577a72110fbaa8, Transactions: 1
# Processing address 239/3000 (7.93%), Address: 0x16e971f967550b51c9794b1a70c6c314921f1d77, Transactions: 2
# Processing address 240/3000 (7.97%), Address: 0x14d195ec10bc7bf2c1135543f595f546f2a2832b, Transactions: 3
# Processing address 241/3000 (8.00%), Address: 0x030a06892a3c3dbd65c0fdeced37ecab8e0f6cb6, Transactions: 1
# Processing address 242/3000 (8.03%), Address: 0xd4a17c41e8c95e1176437fbfebaee76acb3f7dac, Transactions: 1
# Processing address 243/3000 (8.07%), Address: 0x447531c7e1d3028cea6aa232ac1d1988b9acd777, Transactions: 1
# Processing address 244/3000 (8.10%), Address: 0xacf86591f56615183aa628191592d8bbac99cb0c, Transactions: 0
# Processing address 245/3000 (8.13%), Address: 0x05a3fb3655b04824af69c7f51efa21636144c0cb, Transactions: 1
# Processing address 246/3000 (8.17%), Address: 0x339a00fd66e8b4a2861e654de5bb8d81abcf4aa0, Transactions: 2
# Processing address 247/3000 (8.20%), Address: 0xebd11d8057eda12eaa000bc541b44f3f4fa0576d, Transactions: 1
# Processing address 248/3000 (8.23%), Address: 0xaee0c271a44460f99ba82b9afac209648a5db18e, Transactions: 1
# Processing address 249/3000 (8.27%), Address: 0x0e93c64ca58ba4951dcfd7e08ef1f05ec73ef4df, Transactions: 1
# Processing address 250/3000 (8.30%), Address: 0xad0073eeb631f3f51d91012075fc4c34ed4bda1c, Transactions: 1
# Processing address 304/3000 (10.10%), Address: 0x57f1e49aa56242ff6a81442ebeb7875c86c4533c, Transactions: 1
# Processing address 305/3000 (10.13%), Address: 0x7374303c624c485a12c8f0fac7fad2e5909b3186, Transactions: 1
# Processing address 306/3000 (10.17%), Address: 0x33307b891145a2016899f9fd7f08b172265581b3, Transactions: 1
# Processing address 307/3000 (10.20%), Address: 0xfa2124a15728c9f15ae2c6e297a28e60a0d166a6, Transactions: 1
# Processing address 308/3000 (10.23%), Address: 0x973c144e6f664e1f2899617afbb0f6c33287b3a0, Transactions: 1
# Processing address 309/3000 (10.27%), Address: 0xd7a1d409eca91a84741f9e2f179fd9ffae474ee7, Transactions: 1
# Processing address 310/3000 (10.30%), Address: 0x08e66d7e836121ed9ec2fadc809b211fd63a3c08, Transactions: 1
# Processing address 311/3000 (10.33%), Address: 0x0eac5b333fa66010c6a6e7fee10afa30121c430c, Transactions: 1
# Processing address 312/3000 (10.37%), Address: 0xb1f8f37eb225816a2ef820b63ab4c58cec2a53fa, Transactions: 1
# Processing address 313/3000 (10.40%), Address: 0xcdbf29ae4dbb05dd304a4016548cb25d3ba7ff43, Transactions: 2
# Processing address 314/3000 (10.43%), Address: 0xe957e1845f030682256f13d7487c3df56b4d9baa, Transactions: 1
# Processing address 315/3000 (10.47%), Address: 0x33ad0527a789d05fb6aac4d90fa5cbe84df7cadd, Transactions: 1
# Processing address 316/3000 (10.50%), Address: 0xca7e065559c197001904b088ec602b382325a6cc, Transactions: 1
# Processing address 317/3000 (10.53%), Address: 0x4f3bd1c8e48acc10dd86ff9857ca136ae590f2e2, Transactions: 2
# Processing address 318/3000 (10.57%), Address: 0x1feb7e038df541cae8ca9b9c87599594ce23083f, Transactions: 3
# Processing address 319/3000 (10.60%), Address: 0xf61847e0468c40cf78a99672b46cef420df51801, Transactions: 1
# Processing address 320/3000 (10.63%), Address: 0x0e0ebb180b30a19c6a655246212883b8c445b9ed, Transactions: 1
# Processing address 321/3000 (10.67%), Address: 0xa378f9c5bc8423ae02d5ac83d4b5645738140f08, Transactions: 2
# Processing address 322/3000 (10.70%), Address: 0xd78a91337832ba5551cff7784e325044c6aa9834, Transactions: 1
# Processing address 323/3000 (10.73%), Address: 0x0050936b7c19fc67837aad64ab7370515a9f4d38, Transactions: 1
# Processing address 324/3000 (10.77%), Address: 0x30833f1dd674ddb2227f17192b3180daee64a917, Transactions: 1
# Processing address 325/3000 (10.80%), Address: 0x3933e47558557ed5b8001de40a7feb90703fab56, Transactions: 1
# Processing address 326/3000 (10.83%), Address: 0x7786bf9c5ffae49d7c39fbe14873b6be960fca40, Transactions: 1
# Processing address 327/3000 (10.87%), Address: 0xc4c3db95f7d98c736fca731ac7056636d427130d, Transactions: 1
# Processing address 328/3000 (10.90%), Address: 0x2889c5555529b338bf68ed94d3f879ca2949bf50, Transactions: 1
# Processing address 329/3000 (10.93%), Address: 0xef6a555c21dc385fef61c1b251faeffb43f793d9, Transactions: 1
# Processing address 330/3000 (10.97%), Address: 0xd85a3415d5be7e09503dced64ab8ec9eda5edc04, Transactions: 2
# Processing address 331/3000 (11.00%), Address: 0xae89e3158a5cb76369854ef68812c66ed387555d, Transactions: 1
# Processing address 332/3000 (11.03%), Address: 0x44b8d03055cda59c2873f6e09f68918bc5dcb3cc, Transactions: 1
# Processing address 333/3000 (11.07%), Address: 0x9b253c33a9aa66028496f6597341b229b08455ae, Transactions: 1
# Processing address 334/3000 (11.10%), Address: 0x545f10dd1b2048084ca2c136d1c8a11c98fa4c14, Transactions: 1
# Processing address 335/3000 (11.13%), Address: 0x9edb0aa5b7962cd7b34f258653edb8119863f50b, Transactions: 1
# Processing address 336/3000 (11.17%), Address: 0xb4a5f03ab7df10c9f12cc0082b8b8f222bc99778, Transactions: 2
# Processing address 337/3000 (11.20%), Address: 0xb80345530bb9696336eb3fb43865fe469acdfb22, Transactions: 1
# Processing address 338/3000 (11.23%), Address: 0xdbb496ed29dd6b45a6e180a9fbf326e4cc9ba35d, Transactions: 1
# Processing address 339/3000 (11.27%), Address: 0x5080af794514c44b9c291b483271563a97beee6f, Transactions: 1
# Processing address 340/3000 (11.30%), Address: 0xadd99cd26dd0f26f65b27d73df02efe97310eba1, Transactions: 2
# Processing address 341/3000 (11.33%), Address: 0x788105220520108c2b1d6c97b92b1261d64af839, Transactions: 1
# Processing address 342/3000 (11.37%), Address: 0xd10dd249effb0346aa790be99bfaaf90dfd911c5, Transactions: 1
# Processing address 343/3000 (11.40%), Address: 0xa547269102b5e121a64721dbe765960e6fd9e2fb, Transactions: 1
# Processing address 344/3000 (11.43%), Address: 0xa74ef48eb70cb39b81e470b57d4b06de47d7ef6f, Transactions: 2
# Processing address 345/3000 (11.47%), Address: 0x798ded3957d271de9e0cb32d7fae1ed797bc83f7, Transactions: 1
# Processing address 346/3000 (11.50%), Address: 0x1feb9b1ba54134e01d790d4e8192a99666b0083f, Transactions: 1
# Processing address 347/3000 (11.53%), Address: 0x4c1baf53c7e7b487376de572aa29bcf6f1c4be7e, Transactions: 5
# Processing address 348/3000 (11.57%), Address: 0x00196b17414f00f48ea3189c81b3540b4768bde9, Transactions: 1
# Processing address 349/3000 (11.60%), Address: 0xcacba89340d193d4d87076840ff3850022624f64, Transactions: 1
# Processing address 350/3000 (11.63%), Address: 0x8e2e482111cf4a366fcdc81c07f2d6039c576251, Transactions: 1
# Processing address 351/3000 (11.67%), Address: 0x96cb314c8d8754a4a86e3b60343f4c09bff1e565, Transactions: 1
# Processing address 352/3000 (11.70%), Address: 0x2e8dec405ad19239a0597e26a5fd661fce97eba7, Transactions: 1
# Processing address 353/3000 (11.73%), Address: 0xecba3bb773f9cf56b5b2325a7b0d054cd2303650, Transactions: 1
# Processing address 354/3000 (11.77%), Address: 0x039b671d1ccf447ebfa69b9e81e4259125c45b20, Transactions: 1
# Processing address 355/3000 (11.80%), Address: 0x025f138c9b059fafd704146ee7073859df050dcb, Transactions: 1
# Processing address 356/3000 (11.83%), Address: 0x6f6b9e8652fd3dfd02e1c08483aa9db836b20bd2, Transactions: 1
# Processing address 357/3000 (11.87%), Address: 0x3fc77fe5746f1eb54524f36e0f9a530c8c351951, Transactions: 1
# Processing address 358/3000 (11.90%), Address: 0x86fb3abfedf250d323ea8971a0a56e0355eb6d79, Transactions: 2
# Processing address 359/3000 (11.93%), Address: 0xafce9212f3b46147d243d1e21f89d2826623bed9, Transactions: 1
# Processing address 360/3000 (11.97%), Address: 0x25bade711e3b018e83c09f77cc8c0db7f9c56491, Transactions: 2
# Processing address 361/3000 (12.00%), Address: 0x4203450f7721344f5374d3044ed92f9ea1c35c3d, Transactions: 5
# Processing address 362/3000 (12.03%), Address: 0x6a7ae74fda247f1aaa75309396192ad6546f33bc, Transactions: 1
# Processing address 363/3000 (12.07%), Address: 0xd3fd40a29dee6d80f036885fbb0d53e0030e0777, Transactions: 1
# Processing address 364/3000 (12.10%), Address: 0x41364de63d6a97c97fe1d292c498410be2f8bb23, Transactions: 1
# Processing address 365/3000 (12.13%), Address: 0xfb35c64d0b86f81beef2b0221fc88f28ab30b55c, Transactions: 2
# Processing address 366/3000 (12.17%), Address: 0xf7cb5bf96452901451e3554b4bc82082a8b56a10, Transactions: 1
# Processing address 367/3000 (12.20%), Address: 0xef65f3f21c8d799637c089d7ea3824fe61746d17, Transactions: 1
# Processing address 368/3000 (12.23%), Address: 0xcfce35ad182375cc59cc904c6a3cb84170f6314a, Transactions: 1
# Processing address 369/3000 (12.27%), Address: 0xa3f2fa7e86d765509222c34cac4f2636001391a5, Transactions: 2
# Processing address 370/3000 (12.30%), Address: 0x05e65c7319300a1432ae69c54479144056263fbc, Transactions: 2
# Processing address 371/3000 (12.33%), Address: 0xed365fc1000104a8cc8d8d0cd80d02de1a3c2a93, Transactions: 1
# Processing address 372/3000 (12.37%), Address: 0xbfb77d289703a75b03b1341ee9d5ddd2dcd7a369, Transactions: 2
# Processing address 373/3000 (12.40%), Address: 0xa9718e1e84d5b6346c55c673f3597d14d56e65b3, Transactions: 1
# Processing address 374/3000 (12.43%), Address: 0xd2fced0c5360718dc5efe53097ec12c288fc1ec8, Transactions: 1
# Processing address 375/3000 (12.47%), Address: 0x516e5676c9b527edd1e01289fc91485c6ca30127, Transactions: 2
# Processing address 376/3000 (12.50%), Address: 0x6917fe5006ce27f8d3621d070ec99b0fd88e6387, Transactions: 2
# Processing address 377/3000 (12.53%), Address: 0x434ac702a9e956ecfcaca2445f873e15da5604c0, Transactions: 1
# Processing address 378/3000 (12.57%), Address: 0xe2d55ac8b66194ad0a1e4922b3c3a91740fb42bc, Transactions: 2
# Processing address 379/3000 (12.60%), Address: 0xb58b88ee200ebc8e0fb8c6b36ca6f3891d23732e, Transactions: 2
# Processing address 380/3000 (12.63%), Address: 0x84823969cca6f53f4c09f762051b52d4ae1d550b, Transactions: 1
# Processing address 381/3000 (12.67%), Address: 0xea20f38592729b2d4c8f6c93db3209690578db15, Transactions: 1
# Processing address 382/3000 (12.70%), Address: 0x56840fcbd1b836538df625e96a324042854be270, Transactions: 1
# Processing address 383/3000 (12.73%), Address: 0xeb1e2045e1625f4864f918afcc3443278a71b2b5, Transactions: 1
# Processing address 384/3000 (12.77%), Address: 0xa87e620db1c81273f5a89c5d8d8e46566c38b9c1, Transactions: 2
# Processing address 385/3000 (12.80%), Address: 0x45aaadd5add2dd3586a8d5bf5ede781daa6f02fb, Transactions: 1
# Processing address 386/3000 (12.83%), Address: 0x9f00345c5c492e28230fd09892677e62e6f03cd7, Transactions: 2
# Processing address 387/3000 (12.87%), Address: 0x46ffe08a3a805cdd20bd3fc3951fc090736b6f6f, Transactions: 1
# Processing address 388/3000 (12.90%), Address: 0xb7c3373eb1e44d104d2f4f9de61a517dea557019, Transactions: 1
# Processing address 389/3000 (12.93%), Address: 0xbab6221ac8d995f2e8f17ed0d54d7a3981d12297, Transactions: 4
# Processing address 390/3000 (12.97%), Address: 0x072368081e8668f3b0c9aeba6212a5bcd7444667, Transactions: 1
# Processing address 391/3000 (13.00%), Address: 0xb6ce81fa26e83bfd38cadb507a5e8ecb850aa1df, Transactions: 1
# Processing address 392/3000 (13.03%), Address: 0x101dc19f0392136fc9d3855a800ec76fd9352000, Transactions: 1
# Processing address 393/3000 (13.07%), Address: 0x500ae3d4f3e49ed76ce0a684864ae63e5d4a8bb3, Transactions: 1
# Processing address 394/3000 (13.10%), Address: 0xeb4cd5653100ce0903cfb619b3267a39deb81460, Transactions: 1
# Processing address 395/3000 (13.13%), Address: 0x2df9304bcf57f16d8a38761025b20aae41e6028d, Transactions: 2
# Processing address 396/3000 (13.17%), Address: 0x612a3c4635db3f645d8d6fa465ef97a4f10b14ef, Transactions: 1
# Processing address 397/3000 (13.20%), Address: 0x6218228ec07bf1f75b7239da8dbc08b1815c5fe2, Transactions: 2
# Processing address 398/3000 (13.23%), Address: 0x1f7be6fa90d1e95b3a81ebb3e8ac58a575c51a4f, Transactions: 2
# Processing address 399/3000 (13.27%), Address: 0x09afeff108fb09c9736329ecc2420cb5b90f1515, Transactions: 1
# Processing address 400/3000 (13.30%), Address: 0x5b49426f87deda19b6ebe33579aaf6e185a00f4f, Transactions: 1
# Processing address 401/3000 (13.33%), Address: 0xf8c926cc3aca43a233c29820aac62b885f85ec25, Transactions: 1
# Processing address 402/3000 (13.37%), Address: 0xdb6ef4899259d921e4fc1fa48fc4dd652bd04cf7, Transactions: 1
# Processing address 403/3000 (13.40%), Address: 0x1f33d1c41b0faf49cc4a28c552decd8f4ceb6e9c, Transactions: 1
# Processing address 404/3000 (13.43%), Address: 0x19cc577304bf7cf295eb9a1530a05b0cff435fe2, Transactions: 1
# Processing address 405/3000 (13.47%), Address: 0x002a453f87c91890565a8a1eadff940e6494138a, Transactions: 2
# Processing address 406/3000 (13.50%), Address: 0xca5021f5549443d61c998e4c09fb8cba85c66daa, Transactions: 0
# Processing address 407/3000 (13.53%), Address: 0x4d7bd33655e2d32bc2a05ac7f70fb80c33439ee2, Transactions: 0
# Processing address 408/3000 (13.57%), Address: 0x668ec487bbff2a2c3835f1cd3fe3131265a545fd, Transactions: 0
# Processing address 409/3000 (13.60%), Address: 0xda5ccdea7af7c00d9f7031602729e8b5ca4f3409, Transactions: 0
# Processing address 410/3000 (13.63%), Address: 0x6594619be07f6d767b0b1b3ceec5329bfe2f93ab, Transactions: 0
# Processing address 411/3000 (13.67%), Address: 0xf3d6d25c229f3a59bde8a64b5e359aef92fece9e, Transactions: 0
# Processing address 439/3000 (14.60%), Address: 0xb78bcfb164acfd2f9eaee8bd4154263ba6c0df22, Transactions: 0
# Processing address 440/3000 (14.63%), Address: 0xe8339a64def728daecc7df0571599e2b479ebf3a, Transactions: 0
# Processing address 441/3000 (14.67%), Address: 0x8459cd80c92072f1028bfa9e917a99ed1c3c1f6e, Transactions: 0
# Processing address 442/3000 (14.70%), Address: 0x4f9a6513846ded2dec09f7e050b8fb3e29fedfe9, Transactions: 0
# Processing address 443/3000 (14.73%), Address: 0x87751492d7cc7c47f13cfee44e0704e98dbe82ac, Transactions: 0
# Processing address 444/3000 (14.77%), Address: 0xfdd618e1d326a15a13e1e9b3a030563e2b3775a9, Transactions: 0
# Processing address 445/3000 (14.80%), Address: 0x5769effd2c09a61887a0b0db6bce672a4c023a1b, Transactions: 0
# Processing address 446/3000 (14.83%), Address: 0xcbf37c3b415f42bed167c5bb672f6a168771b816, Transactions: 0
# Processing address 447/3000 (14.87%), Address: 0x5561a78602135dc03b7bbfecb74d88c7dadf3e9c, Transactions: 0
# Processing address 448/3000 (14.90%), Address: 0x2efb0680171caf9543e92f3ea8f9c80707b17eca, Transactions: 0
# Processing address 449/3000 (14.93%), Address: 0x5d17ce1b5c86aaadcaf3fe0b2c5320c961d9ce14, Transactions: 0
# Processing address 450/3000 (14.97%), Address: 0x7bddff143100f3bbb81775e2a561c998ed5c753b, Transactions: 0
# Processing address 451/3000 (15.00%), Address: 0xd9727218aadf20c9b736833945636d4780ecede6, Transactions: 0
# Processing address 452/3000 (15.03%), Address: 0xba6decb5a100eb59ae80a75cff9d1aea4ac2f8b1, Transactions: 0
# ...
# Processing address 2854/3000 (95.10%), Address: 0x180402c5e691ea5775cbc280e00b9a8c1402f80a, Transactions: 1
# Processing address 2855/3000 (95.13%), Address: 0x64026fab7a5176eeb2de2547f9dd1fe8a68c7144, Transactions: 1
# Processing address 2856/3000 (95.17%), Address: 0x4755971ee3c146f45d41271350619da6a8c8ed67, Transactions: 1
# Processing address 2857/3000 (95.20%), Address: 0xfe85503ec3cff0e17d336d768395e7075af6a282, Transactions: 5
# Processing address 2858/3000 (95.23%), Address: 0x691bd067f3d01a8250cb41cdf6f731c84719bbd0, Transactions: 1
# Processing address 2859/3000 (95.27%), Address: 0x2b5ee17b8b8761206f10eb9669439bd79831652c, Transactions: 1
# Processing address 2860/3000 (95.30%), Address: 0x2f1dd03381b35bd58929d3b4cd14cff0555fc3ff, Transactions: 1
# Processing address 2861/3000 (95.33%), Address: 0xead9a60cf61fd4668e5e11232ee7861c33affb1b, Transactions: 22
# Processing address 2862/3000 (95.37%), Address: 0xef0c3f358afe24a839eeb95f81b7bf43a947ac0e, Transactions: 0
# Processing address 2863/3000 (95.40%), Address: 0xbdfff4646df6919914126bd16c4dc192cf201039, Transactions: 1
# Processing address 2864/3000 (95.43%), Address: 0xa50f355d6e64d6df714652dc138be230012142d6, Transactions: 3
# Processing address 2865/3000 (95.47%), Address: 0x072fbc9b2d0f749a1eaea95a51570f70362da281, Transactions: 1
# Processing address 2866/3000 (95.50%), Address: 0x2f7f835b5df8792965d240c44355f237efd72a10, Transactions: 1
# Processing address 2867/3000 (95.53%), Address: 0x62dc716b3148c778c7187ba2828be6bd9510e1f0, Transactions: 1
# Processing address 2868/3000 (95.57%), Address: 0xd13b2a43f91adfa792268e71b6fe7e4b3afce610, Transactions: 1
# Processing address 2869/3000 (95.60%), Address: 0x08871f8139f286909ccf3c013d5fc14655811dd1, Transactions: 3
# Processing address 2870/3000 (95.63%), Address: 0xc8282742798503b2cf0b4b9e188a4d7d720a40d3, Transactions: 1
# Processing address 2871/3000 (95.67%), Address: 0x853c85d8621cbcc0af9ea3429adcdd170bb60fc8, Transactions: 5
# Processing address 2872/3000 (95.70%), Address: 0xaa0c3a79590603336baa45c98c5032584b7cb307, Transactions: 2
# Processing address 2873/3000 (95.73%), Address: 0x4c194738c4fb832630690f232431db9ca638f1db, Transactions: 2
# Processing address 2874/3000 (95.77%), Address: 0x8fe9edea9073b82b8caee4698bbaa7b5c5230ae9, Transactions: 1
# Processing address 2875/3000 (95.80%), Address: 0xcc30a9fcef31084c7d8c5f370a198879bed41729, Transactions: 14
# Processing address 2876/3000 (95.83%), Address: 0xbe3fa5c7ef5dcbabda4ab83420c70f7e2ea8033e, Transactions: 2
# Processing address 2877/3000 (95.87%), Address: 0x24085e118bdc9918c3fd51bcbc8269ed041ed006, Transactions: 1
# Processing address 2878/3000 (95.90%), Address: 0xfb311962d470daebc1935dc22b1322e77762649d, Transactions: 4
# Processing address 2879/3000 (95.93%), Address: 0xf8a784c23105d6b5b8b7382457cb23399258c3e1, Transactions: 4
# Processing address 2880/3000 (95.97%), Address: 0xea58d0f41f3162608a717443bb61677e8a75bac6, Transactions: 1
# Processing address 2881/3000 (96.00%), Address: 0x19dad13d48146e12c0966b7eaf3f30bba934d8a6, Transactions: 2
# Processing address 2882/3000 (96.03%), Address: 0xe3f8071d60388878189aa162bbbe68b251d4fc69, Transactions: 1
# Processing address 2883/3000 (96.07%), Address: 0xf42095d156d4a6ac0aa942614c16c179795cd893, Transactions: 1
# Processing address 2884/3000 (96.10%), Address: 0x02318bc4c06a5ad3d11fbe06a4a9a663746bbf1d, Transactions: 2
# Processing address 2885/3000 (96.13%), Address: 0x1692b334ee77ffb34a69c29fe914b2c5021d6935, Transactions: 2
# Processing address 2886/3000 (96.17%), Address: 0x4ccef6243096eff50c3123a0a2b23d108fbbcb88, Transactions: 1
# Processing address 2887/3000 (96.20%), Address: 0xb7d99981ae9afa88756ebe212a41a07e464c621a, Transactions: 0
# Processing address 2888/3000 (96.23%), Address: 0x3b59506ee6869bd011851f1d0156d80a79a0ef23, Transactions: 2
# Processing address 2889/3000 (96.27%), Address: 0x7cf87a8e90cc557f333a09d75412f079158240c9, Transactions: 2
# Processing address 2890/3000 (96.30%), Address: 0x369ea490c9f8975a339721d01b42ba444d0a49a2, Transactions: 1
# Processing address 2891/3000 (96.33%), Address: 0x01c4cc63daad6d6b7731fd02944fc56c2f17d1f0, Transactions: 1
# Processing address 2892/3000 (96.37%), Address: 0x7e5fed128a293dc24eba8ada1307f37a214df2aa, Transactions: 2
# Processing address 2998/3000 (99.90%), Address: 0x704d83a4ecdf05d9edbb3bad8c5c493496c029f0, Transactions: 1
# Processing address 2999/3000 (99.93%), Address: 0xe984535917186fa59efb58e994ec00efe00dc3a2, Transactions: 5
# Processing address 3000/3000 (99.97%), Address: 0x3a992656ddcbbaaf8ec41b9e9120a48a6eb4d5a6, Transactions: 1
# Processing complete.

# %% [markdown]
# ### combine the two csv files for address poisining

# %%
def combine_csv_files(file1, file2, output_file):
    with open(output_file, mode='w', newline='') as out_file:
        writer = csv.writer(out_file)

        # Read and write the first file
        with open(file1, mode='r') as f1:
            reader1 = csv.reader(f1)
            header = next(reader1)  # Read the header
            writer.writerow(header)  # Write the header to the output file
            for row in reader1:
                writer.writerow(row)

        # Read and write the second file (without writing the header again)
        with open(file2, mode='r') as f2:
            reader2 = csv.reader(f2)
            next(reader2)  # Skip the header
            for row in reader2:
                writer.writerow(row)

# Example usage
combine_csv_files('dataset/address_poisoning_transactions.csv', 'dataset/non_address_poisoning_transactions.csv', 'dataset/address_poisoning_dataset.csv')

# %% [markdown]
# # PART 2: Constructing the transaction graph based dataset

# %% [markdown]
# ### Define input and output file paths

# %%
input_csv = 'dataset/address_poisoning_dataset.csv'
nodes_csv = 'dataset/nodes.csv'
edges_csv = 'dataset/edges.csv'
checkpoint_file = 'trasnaction_graph_checkpoint.txt'

# %% [markdown]
# ### Initialize checkpoints

# %%
def read_checkpoint():
    if os.path.exists(checkpoint_file):
        with open(checkpoint_file, 'r') as file:
            return int(file.readline().strip())
    return 0

def write_checkpoint(last_processed_row):
    with open(checkpoint_file, 'w') as file:
        file.write(str(last_processed_row))

# %% [markdown]
# ### Initialize CSV files if not already present

# %%
def initialize_csv_files():
    if not os.path.exists(nodes_csv):
        with open(nodes_csv, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['address'])

    if not os.path.exists(edges_csv):
        with open(edges_csv, 'w', newline='') as file:
            writer = csv.writer(file)
            # Write headers (same as input CSV except 'from' and 'to' replaced by 'source' and 'target')
            writer.writerow([
                'source', 'target', 'hash', 'tx_index', 'gas_price_in_wei', 
                'gas_used', 'block_id', 'block_timestamp', 'total_eth_transfer', 
                'total_deployment', 'total_erc20_transfer', 'status', 'base_fee', 
                'max_fee', 'priority_fee', 'input', 'reverse_hash', 'total_erc721_transfer', 
                'total_internal_transfer', 'index_in_tx', 'contract_id', 'crypto_amount', 'type', 'class'
            ])

# %% [markdown]
# ### Append new rows to Nodes and Edges CSV files

# %%
def process_transactions(start_index=0):
    nodes_set = set()  # To track unique addresses
    last_processed_row = start_index

    with open(input_csv, 'r') as infile, \
         open(nodes_csv, 'a', newline='') as nodes_outfile, \
         open(edges_csv, 'a', newline='') as edges_outfile:

        reader = csv.DictReader(infile)
        nodes_writer = csv.writer(nodes_outfile)
        edges_writer = csv.writer(edges_outfile)

        for index, row in enumerate(reader):
            if index < start_index:
                continue

            # Update last processed row
            last_processed_row = index + 1

            # Extract source and target addresses
            source = row['from']
            target = row['to']

            # Add addresses to the Nodes CSV if they are not already present
            if source not in nodes_set:
                nodes_writer.writerow([source])
                nodes_set.add(source)

            if target not in nodes_set:
                nodes_writer.writerow([target])
                nodes_set.add(target)

            # Write the transaction data to the Edges CSV
            edges_writer.writerow([
                source, target, row['hash'], row['tx_index'], row['gas_price_in_wei'], 
                row['gas_used'], row['block_id'], row['block_timestamp'], row['total_eth_transfer'], 
                row['total_deployment'], row['total_erc20_transfer'], row['status'], row['base_fee'], 
                row['max_fee'], row['priority_fee'], row['input'], row['reverse_hash'], 
                row['total_erc721_transfer'], row['total_internal_transfer'], row['index_in_tx'], 
                row['contract_id'], row['crypto_amount'], row['type'], row['class']
            ])

            # Periodically update the checkpoint
            if index % 100 == 0:  # Adjust this number as needed
                write_checkpoint(last_processed_row)

    # Final checkpoint update
    write_checkpoint(last_processed_row)

# %%
    # Initialize CSV files if needed
    initialize_csv_files()

    # Read the last processed row from the checkpoint
    start_index = read_checkpoint()

    # Process the transactions starting from the last checkpoint
    process_transactions(start_index)

# %% [markdown]
# ## Visualize the dataset

# %% [markdown]
# ### Load Data

# %%
input_df = pd.read_csv(input_csv)
nodes_df = pd.read_csv(nodes_csv)
edges_df = pd.read_csv(edges_csv)

# %%
# Function to visualize a small sample of the CSV data
def visualize_data_table(input_df, sample_size=10, title="Sample of Input CSV Data"):
    sample_df = input_df.head(sample_size)
    display(sample_df)



visualize_data_table(input_df)
visualize_data_table(nodes_df)
visualize_data_table(edges_df)
# Out:
#                                          from  \
# 0  0x4e5b2e1dc63f6b91cb6cd759936495434c7e972f
# 1  0xf9a55bae633213a4c283bac774e766357d86d9a6
# 2  0xf9a55bae633213a4c283bac774e766357d86d9a6
# 3  0x111111125421ca6dc452d289314280a0f8842a65
# 4  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 5  0xf9a55bae633213a4c283bac774e766357d86d9a6
# 6  0xd0ccf523d198a9e0ef6222ad3d3e3f1919898725
# 7  0x52836874a60b2e0a025e250e36a1cf87706d7586
# 8  0x4a98561c965dad79e4915a814d8df0362d492c99
# 9  0xb5551a2bd3d79a89555a15e45c3b420b6147bfef
#
#                                            to  \
# 0  0xf9a55bae633213a4c283bac774e766357d86d9a6
# 1  0x18d88d253ded3f2c52937a081536697697669025
# 2  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 3  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 4  0xdf0770df86a8034b3efef0a1bb3c889b8332ff56
# 5  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 6  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 7  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 8  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 9  0x808a05462b648ae72451347c9a5f4e75cc16be62
#
#                                                 hash  tx_index  \
# 0  0x5c882ccd71f00ce881610c3252a9d750ec1dda08503e...        69
# 1  0x52241247656d851301242d1f3faa81484029ad8b1ac5...        69
# 2  0x4b3f040c5397df6978394522f927fc312fa69b0ed45f...        48
# 3  0x3e9d3fa814f83ff4aab5344439a838882d4a74276279...       140
# 4  0xa4d78141fad025229d9de36ab0ed3992d9eb2123dc3a...       248
# 5  0x4b3f040c5397df6978394522f927fc312fa69b0ed45f...        48
# 6  0x378c29c4dd7d9bae50f32bbaae74d4e211e9824280b7...        47
# 7  0xb9f655319a2adb4cd7bbb43a4f5d074eb3038b0ab8ba...        43
# 8  0x75727e9af536c8fc64dcfeb11c2ef9ad9ada48541562...        73
# 9  0x2196afac62b16ae4c8212aa027955f52cf325cf5d9d1...        72
#
#    gas_price_in_wei  gas_used  block_id  block_timestamp  total_eth_transfer  \
# 0       38000000000     21000  18668579       1701155819                   1
# 1       29771233875    359666  18670143       1701174743                   0
# 2       40450120072     21000  18681698       1701314399                   1
# 3       27329864495    169801  19525509       1711540703                   3
# 4       27350588836    372077  19525548       1711541171                   4
# 5       40450120072     21000  18681698       1701314399                   1
# 6       40450120072     21000  18681698       1701314399                   1
# 7       31052120199     21000  18683169       1701332135                   1
# 8       23831767409     21000  18944494       1704499367                   1
# 9       23831767409     21000  18944494       1704499367                   1
#
#    total_deployment  ...  priority_fee      input  \
# 0                 0  ...             0   47227150
# 1                 1  ...    1000000000  285049725
# 2                 0  ...             0  285049725
# 3                 0  ...       4850000  294399623
# 4                 0  ...      84681000  285243032
# 5                 0  ...             0  285049725
# 6                 0  ...             0  285049330
# 7                 0  ...             0  284845184
# 8                 0  ...             0  285879965
# 9                 0  ...             0  286126833
#
#                                         reverse_hash total_erc721_transfer  \
# 0  0913d0572f42236bd1c1e30580add1ce057d9a2523c016...                     0
# 1  cc2654c39f100fd0ddc25ca1b8da92048418aaf3f1d242...                     0
# 2  db8dec57771cbda64119f54de0b96af213cf729f225493...                     0
# 3  86a1d9898f7284217e5597267247a4d288838a9344435b...                     0
# 4  719a82288430fcab3a87a3cd3212be9d2993de0ba63ed9...                     0
# 5  db8dec57771cbda64119f54de0b96af213cf729f225493...                     0
# 6  495bc0310a344ffc70e77b0824289e112e4d47eaabb23f...                     0
# 7  33f64d1a9498a0b0bd2dab8ba0b8303be470d5f4a34bbb...                     0
# 8  323af89071534100a53e26514584ada9da9fe2c11befcd...                     0
# 9  8383d2c5e45b4e21f6791d9d5fc523fc25f559720aa212...                     0
#
#   total_internal_transfer  index_in_tx contract_id         crypto_amount  \
# 0                       0         None        None  197104000000000000.0
# 1                       0         None        None                   0.0
# 2                       0         None        None  185546846875602240.0
# 3                       2            3    45676948            6915.08385
# 4                       3            0    45676948            6915.08385
# 5                       0         None        None  185546846875602240.0
# 6                       0         None        None  173208569975300032.0
# 7                       0         None        None   15452408475564982.0
# 8                       0         None        None   30942435103770216.0
# 9                       0         None        None   15404409426743966.0
#
#     type class
# 0    eth     1
# 1    eth     1
# 2    eth     1
# 3  erc20     1
# 4  erc20     1
# 5    eth     1
# 6    eth     1
# 7    eth     1
# 8    eth     1
# 9    eth     1
#
# [10 rows x 24 columns]
#                                       address
# 0  0x4e5b2e1dc63f6b91cb6cd759936495434c7e972f
# 1  0xf9a55bae633213a4c283bac774e766357d86d9a6
# 2  0x18d88d253ded3f2c52937a081536697697669025
# 3  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 4  0x111111125421ca6dc452d289314280a0f8842a65
# 5  0xdf0770df86a8034b3efef0a1bb3c889b8332ff56
# 6  0xd0ccf523d198a9e0ef6222ad3d3e3f1919898725
# 7  0x52836874a60b2e0a025e250e36a1cf87706d7586
# 8  0x4a98561c965dad79e4915a814d8df0362d492c99
# 9  0xb5551a2bd3d79a89555a15e45c3b420b6147bfef
#                                        source  \
# 0  0x4e5b2e1dc63f6b91cb6cd759936495434c7e972f
# 1  0xf9a55bae633213a4c283bac774e766357d86d9a6
# 2  0xf9a55bae633213a4c283bac774e766357d86d9a6
# 3  0x111111125421ca6dc452d289314280a0f8842a65
# 4  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 5  0xf9a55bae633213a4c283bac774e766357d86d9a6
# 6  0xd0ccf523d198a9e0ef6222ad3d3e3f1919898725
# 7  0x52836874a60b2e0a025e250e36a1cf87706d7586
# 8  0x4a98561c965dad79e4915a814d8df0362d492c99
# 9  0xb5551a2bd3d79a89555a15e45c3b420b6147bfef
#
#                                        target  \
# 0  0xf9a55bae633213a4c283bac774e766357d86d9a6
# 1  0x18d88d253ded3f2c52937a081536697697669025
# 2  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 3  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 4  0xdf0770df86a8034b3efef0a1bb3c889b8332ff56
# 5  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 6  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 7  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 8  0x808a05462b648ae72451347c9a5f4e75cc16be62
# 9  0x808a05462b648ae72451347c9a5f4e75cc16be62
#
#                                                 hash  tx_index  \
# 0  0x5c882ccd71f00ce881610c3252a9d750ec1dda08503e...        69
# 1  0x52241247656d851301242d1f3faa81484029ad8b1ac5...        69
# 2  0x4b3f040c5397df6978394522f927fc312fa69b0ed45f...        48
# 3  0x3e9d3fa814f83ff4aab5344439a838882d4a74276279...       140
# 4  0xa4d78141fad025229d9de36ab0ed3992d9eb2123dc3a...       248
# 5  0x4b3f040c5397df6978394522f927fc312fa69b0ed45f...        48
# 6  0x378c29c4dd7d9bae50f32bbaae74d4e211e9824280b7...        47
# 7  0xb9f655319a2adb4cd7bbb43a4f5d074eb3038b0ab8ba...        43
# 8  0x75727e9af536c8fc64dcfeb11c2ef9ad9ada48541562...        73
# 9  0x2196afac62b16ae4c8212aa027955f52cf325cf5d9d1...        72
#
#    gas_price_in_wei  gas_used  block_id  block_timestamp  total_eth_transfer  \
# 0       38000000000     21000  18668579       1701155819                   1
# 1       29771233875    359666  18670143       1701174743                   0
# 2       40450120072     21000  18681698       1701314399                   1
# 3       27329864495    169801  19525509       1711540703                   3
# 4       27350588836    372077  19525548       1711541171                   4
# 5       40450120072     21000  18681698       1701314399                   1
# 6       40450120072     21000  18681698       1701314399                   1
# 7       31052120199     21000  18683169       1701332135                   1
# 8       23831767409     21000  18944494       1704499367                   1
# 9       23831767409     21000  18944494       1704499367                   1
#
#    total_deployment  ...  priority_fee      input  \
# 0                 0  ...             0   47227150
# 1                 1  ...    1000000000  285049725
# 2                 0  ...             0  285049725
# 3                 0  ...       4850000  294399623
# 4                 0  ...      84681000  285243032
# 5                 0  ...             0  285049725
# 6                 0  ...             0  285049330
# 7                 0  ...             0  284845184
# 8                 0  ...             0  285879965
# 9                 0  ...             0  286126833
#
#                                         reverse_hash total_erc721_transfer  \
# 0  0913d0572f42236bd1c1e30580add1ce057d9a2523c016...                     0
# 1  cc2654c39f100fd0ddc25ca1b8da92048418aaf3f1d242...                     0
# 2  db8dec57771cbda64119f54de0b96af213cf729f225493...                     0
# 3  86a1d9898f7284217e5597267247a4d288838a9344435b...                     0
# 4  719a82288430fcab3a87a3cd3212be9d2993de0ba63ed9...                     0
# 5  db8dec57771cbda64119f54de0b96af213cf729f225493...                     0
# 6  495bc0310a344ffc70e77b0824289e112e4d47eaabb23f...                     0
# 7  33f64d1a9498a0b0bd2dab8ba0b8303be470d5f4a34bbb...                     0
# 8  323af89071534100a53e26514584ada9da9fe2c11befcd...                     0
# 9  8383d2c5e45b4e21f6791d9d5fc523fc25f559720aa212...                     0
#
#   total_internal_transfer  index_in_tx contract_id         crypto_amount  \
# 0                       0         None        None  197104000000000000.0
# 1                       0         None        None                   0.0
# 2                       0         None        None  185546846875602240.0
# 3                       2            3    45676948            6915.08385
# 4                       3            0    45676948            6915.08385
# 5                       0         None        None  185546846875602240.0
# 6                       0         None        None  173208569975300032.0
# 7                       0         None        None   15452408475564982.0
# 8                       0         None        None   30942435103770216.0
# 9                       0         None        None   15404409426743966.0
#
#     type class
# 0    eth     1
# 1    eth     1
# 2    eth     1
# 3  erc20     1
# 4  erc20     1
# 5    eth     1
# 6    eth     1
# 7    eth     1
# 8    eth     1
# 9    eth     1
#
# [10 rows x 24 columns]

# %% [markdown]
# ### Function to visualize the graph

# %%
def visualize_graph(edges_df, nodes_df=None, title="Transaction Graph"):
    G = nx.DiGraph()  # Create a directed graph

    # Add nodes 
    if nodes_df is not None:
        for index, row in nodes_df.iterrows():
            G.add_node(row['address'])

    # Add edges
    for index, row in edges_df.iterrows():
        G.add_edge(row['source'], row['target'], **row.to_dict())

    # Draw the graph
    plt.figure(figsize=(12, 8))
    pos = nx.spring_layout(G)  # Positioning of nodes
    nx.draw(G, pos, with_labels=True, node_size=700, node_color="lightblue", arrows=True, arrowsize=20)
    plt.title(title)
    plt.show()

# %% [markdown]
# ### Visualize the graph using the Edges and Nodes CSV files

# %%
def visualize_graph_subset(edges_df, nodes_df=None, title="Transaction Graph from Subset", sample_size=100):
    G = nx.DiGraph()  

    edges_sample_df = edges_df.sample(n=sample_size)


    if nodes_df is not None:
        sampled_nodes = set(edges_sample_df['source']).union(set(edges_sample_df['target']))
        for node in sampled_nodes:
            G.add_node(node)


    for index, row in edges_sample_df.iterrows():
        G.add_edge(row['source'], row['target'], **row.to_dict())

    # Draw the graph
    plt.figure(figsize=(24, 16))
    pos = nx.spring_layout(G)  
    nx.draw(G, pos, with_labels=True, node_size=200, node_color="lightblue", arrows=True, arrowsize=20)
    plt.title(title)
    plt.show()


visualize_graph_subset(edges_df, nodes_df, title="Transaction Graph from Subset", sample_size=50)
